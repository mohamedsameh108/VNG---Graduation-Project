# %%
import warnings
from requests.exceptions import RequestsDependencyWarning

# Suppress only the noisy warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", message=".*RequestsDependencyWarning.*")
warnings.filterwarnings("ignore", category=RequestsDependencyWarning)
# Out:
# d:\College\Anaconda\envs\gpuacc\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.applications.densenet import preprocess_input as densenet_preprocess
from tensorflow.keras.applications.resnet import preprocess_input as resnet_preprocess

# %%
# ======================
# Build classification DataFrames
# ======================
def create_classification_df(base_dir):
    true_dir = os.path.join(base_dir, "true")
    false_dir = os.path.join(base_dir, "false")

    classification_data = []

    # Collect true images
    for fname in os.listdir(true_dir):
        fpath = os.path.join(true_dir, fname)
        if os.path.isfile(fpath):
            classification_data.append([fpath, 1])   # label = 1

    # Collect false images
    for fname in os.listdir(false_dir):
        fpath = os.path.join(false_dir, fname)
        if os.path.isfile(fpath):
            classification_data.append([fpath, 0])  # label = 0

    # Create DataFrame
    cls_df = pd.DataFrame(classification_data, columns=["image_path", "label"])
    cls_df = cls_df.sample(frac=1, random_state=42).reset_index(drop=True)

    return cls_df


# ======================
# Main dataset paths
# ======================
train_dir = r"D:\\Graduation Project\\data\\Video\\Frames\\Training\\labeled"
val_dir   = r"D:\\Graduation Project\\data\\Video\\Frames\\Validation\\labeled"
test_dir  = r"D:\\Graduation Project\\data\\Video\\Frames\\Testing\\labeled"

train_cls_df = create_classification_df(train_dir)
val_cls_df   = create_classification_df(val_dir)
test_cls_df  = create_classification_df(test_dir)

# ======================
# Save DataFrames
# ======================
train_cls_df.to_csv("train_classification.csv", index=False)
val_cls_df.to_csv("val_classification.csv", index=False)
test_cls_df.to_csv("test_classification.csv", index=False)


# ======================
# Info
# ======================
print("Classification DFs:", len(train_cls_df), len(val_cls_df), len(test_cls_df))
# Out:
# Classification DFs: 1136 224 209

# %%
train_cls_df.head()
# Out:
#                                           image_path  label
# 0  D:\\Graduation Project\\data\\Video\\Frames\\T...      0
# 1  D:\\Graduation Project\\data\\Video\\Frames\\T...      0
# 2  D:\\Graduation Project\\data\\Video\\Frames\\T...      1
# 3  D:\\Graduation Project\\data\\Video\\Frames\\T...      0
# 4  D:\\Graduation Project\\data\\Video\\Frames\\T...      1

# %%
dfs = {
    "Train": train_cls_df,
    "Validation": val_cls_df,
    "Test": test_cls_df
}

plt.figure(figsize=(15, 5))

for i, (name, df) in enumerate(dfs.items(), 1):
    label_counts = df['label'].value_counts()

    plt.subplot(1, 3, i)  # 1 row, 3 columns, i-th plot
    plt.pie(
        label_counts,
        labels=label_counts.index,
        autopct='%1.1f%%',
        startangle=90,
        counterclock=False
    )
    plt.title(f"{name} Label Distribution")

plt.tight_layout()
plt.show()

# %%
# ------------------------
# Preprocessing / Augmentation
# ------------------------
def preprocess(img, label, img_size=(224,224)):
    img = tf.io.read_file(img)
    img = tf.image.decode_jpeg(img, channels=3)   # Convert to RGB
    img = tf.image.resize(img, img_size)
    return img, label

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tfa.image.rotate(img, tf.random.uniform([], -0.261, 0.261))  # ~ -15° to +15°
    img = tf.image.random_brightness(img, 0.1)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    return img, label

def normalize(img, label):
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

# ------------------------
# Dataset builder
# ------------------------
def make_dataset(df, img_size=(224,224), batch_size=4, do_augment=False, shuffle=False, preprocess_fn=None):
    paths = df["image_path"].values
    labels = df["label"].values

    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    if shuffle:
        ds = ds.shuffle(buffer_size=len(df), reshuffle_each_iteration=True)

    # base preprocessing (resize, decode)
    ds = ds.map(lambda x, y: preprocess(x, y, img_size), num_parallel_calls=tf.data.AUTOTUNE)

    # augment only on train set
    if do_augment:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    # normalization: either custom (/255.0) or keras preprocess_input
    if preprocess_fn is not None:
        ds = ds.map(lambda x, y: (preprocess_fn(x), y), num_parallel_calls=tf.data.AUTOTUNE)
    else:
        ds = ds.map(normalize, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

# ResNet datasets
train_ds_resnet = make_dataset(train_cls_df, img_size=(224,224), batch_size=4,
                               do_augment=True, shuffle=True, preprocess_fn=resnet_preprocess)
val_ds_resnet = make_dataset(val_cls_df, img_size=(224,224), batch_size=4,
                             do_augment=False, shuffle=False, preprocess_fn=resnet_preprocess)
test_ds_resnet = make_dataset(test_cls_df, img_size=(224,224), batch_size=4,
                              do_augment=False, shuffle=False, preprocess_fn=resnet_preprocess)

# DenseNet datasets
train_ds_densenet = make_dataset(train_cls_df, img_size=(224,224), batch_size=4,
                                 do_augment=True, shuffle=True, preprocess_fn=densenet_preprocess)
val_ds_densenet = make_dataset(val_cls_df, img_size=(224,224), batch_size=4,
                               do_augment=False, shuffle=False, preprocess_fn=densenet_preprocess)
test_ds_densenet = make_dataset(test_cls_df, img_size=(224,224), batch_size=4,
                                do_augment=False, shuffle=False, preprocess_fn=densenet_preprocess)

print("✅ Datasets ready:")
# Out:
# ✅ Datasets ready:

# %%
# =========================
# 1. Model builder function
# =========================
def build_model(base_model, input_shape):
    base_model.trainable = False  # freeze base model initially
    inputs = tf.keras.Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    
    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# =========================
# 2. Training and evaluation function
# =========================
def train_and_evaluate(model_name, base_model, train_ds, val_ds, test_ds, input_shape, epochs=50):
    print(f"\n🔹 Training {model_name}...")
    model = build_model(base_model, input_shape)
    
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    )
    
    checkpoint = ModelCheckpoint(
        f'best_{model_name}_freezed.h5',
        monitor='val_loss',
        save_best_only=True
    )
    
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[early_stop, checkpoint]
    )
    
    print(f"\n✅ Evaluating {model_name}...")
    results = model.evaluate(test_ds, verbose=0)
    test_loss, test_acc = results[0], results[1]
    print(f"{model_name} Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
    
    # =========================
    # Predictions
    # =========================
    y_true = np.concatenate([y for _, y in test_ds], axis=0)   # ground truth labels
    y_pred_probs = model.predict(test_ds)
    y_pred = (y_pred_probs > 0.5).astype("int32").ravel()
    
    # =========================
    # Classification report
    # =========================
    print(f"\n📊 Classification Report for {model_name}:")
    print(classification_report(y_true, y_pred, digits=4))
    
    # =========================
    # Extra metrics
    # =========================
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred_probs)
    acc = accuracy_score(y_true, y_pred)
    
    print(f"\n📈 Extra Evaluation Metrics for {model_name}:")
    print(f"Accuracy   : {acc:.4f}")
    print(f"Precision  : {precision:.4f}")
    print(f"Recall     : {recall:.4f}")
    print(f"F1-score   : {f1:.4f}")
    print(f"AUC        : {auc:.4f}")
    
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    print("\n🌀 Confusion Matrix:")
    print(cm)
    
    # return model, history, and accuracy
    return model, history, test_acc

# =========================
# 3. Prepare base models
# =========================
# ResNet50 (224x224)
resnet_base = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224,224,3))

# DenseNet121 (224x224)
densenet_base = tf.keras.applications.DenseNet121(include_top=False, weights='imagenet', input_shape=(224,224,3))

# =========================
# 4. Train models
# =========================
resnet_model_freezed, resnet_history_freezed, resnet_acc_freezed = train_and_evaluate(
    "ResNet50", resnet_base, train_ds_resnet, val_ds_resnet, test_ds_resnet, (224,224,3)
)

densenet_model_freezed, densenet_history_freezed, densenet_acc_freezed = train_and_evaluate(
    "DenseNet121", densenet_base, train_ds_densenet, val_ds_densenet, test_ds_densenet, (224,224,3)
)

print("✅ Final Accuracies:")
print("ResNet50:", resnet_acc_freezed)
print("DenseNet121:", densenet_acc_freezed)
# Out:
# 🔹 Training ResNet50...
# Epoch 1/50
# 284/284 [==============================] - 17s 37ms/step - loss: 0.3852 - accuracy: 0.8460 - val_loss: 0.2666 - val_accuracy: 0.8750
# Epoch 2/50
# 284/284 [==============================] - 13s 44ms/step - loss: 0.2646 - accuracy: 0.8829 - val_loss: 0.1938 - val_accuracy: 0.9062
# Epoch 3/50
# 284/284 [==============================] - 13s 45ms/step - loss: 0.2189 - accuracy: 0.9102 - val_loss: 0.1795 - val_accuracy: 0.9062
# Epoch 4/50
# 284/284 [==============================] - 13s 45ms/step - loss: 0.2072 - accuracy: 0.9199 - val_loss: 0.1494 - val_accuracy: 0.9375
# Epoch 5/50
# 284/284 [==============================] - 13s 44ms/step - loss: 0.1808 - accuracy: 0.9208 - val_loss: 0.1110 - val_accuracy: 0.9598
# Epoch 6/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1867 - accuracy: 0.9269 - val_loss: 0.1406 - val_accuracy: 0.9330
# Epoch 7/50
# 284/284 [==============================] - 12s 44ms/step - loss: 0.1705 - accuracy: 0.9331 - val_loss: 0.0798 - val_accuracy: 0.9643
# Epoch 8/50
# 284/284 [==============================] - 13s 46ms/step - loss: 0.1761 - accuracy: 0.9287 - val_loss: 0.0707 - val_accuracy: 0.9732
# Epoch 9/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1619 - accuracy: 0.9305 - val_loss: 0.0767 - val_accuracy: 0.9643
# Epoch 10/50
# 284/284 [==============================] - 13s 46ms/step - loss: 0.1693 - accuracy: 0.9305 - val_loss: 0.0671 - val_accuracy: 0.9732
# Epoch 11/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1546 - accuracy: 0.9261 - val_loss: 0.0864 - val_accuracy: 0.9732
# Epoch 12/50
# 284/284 [==============================] - 14s 48ms/step - loss: 0.1730 - accuracy: 0.9243 - val_loss: 0.0641 - val_accuracy: 0.9821
# Epoch 13/50
# 284/284 [==============================] - 13s 46ms/step - loss: 0.1463 - accuracy: 0.9401 - val_loss: 0.0604 - val_accuracy: 0.9777
# Epoch 14/50
# 284/284 [==============================] - 13s 47ms/step - loss: 0.1372 - accuracy: 0.9331 - val_loss: 0.0595 - val_accuracy: 0.9821
# Epoch 15/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1447 - accuracy: 0.9437 - val_loss: 0.0601 - val_accuracy: 0.9732
# Epoch 16/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1428 - accuracy: 0.9393 - val_loss: 0.1041 - val_accuracy: 0.9688
# Epoch 17/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1403 - accuracy: 0.9445 - val_loss: 0.0629 - val_accuracy: 0.9688
# Epoch 18/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1442 - accuracy: 0.9305 - val_loss: 0.0642 - val_accuracy: 0.9732
# Epoch 19/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1498 - accuracy: 0.9305 - val_loss: 0.0701 - val_accuracy: 0.9732
#
# ✅ Evaluating ResNet50...
# ResNet50 Test Loss: 0.0948, Test Acc: 0.9665
# 53/53 [==============================] - 2s 24ms/step
#
# 📊 Classification Report for ResNet50:
#               precision    recall  f1-score   support
#
#            0     0.9434    0.9259    0.9346        54
#            1     0.9744    0.9806    0.9775       155
#
#     accuracy                         0.9665       209
#    macro avg     0.9589    0.9533    0.9560       209
# weighted avg     0.9664    0.9665    0.9664       209
#
#
# 📈 Extra Evaluation Metrics for ResNet50:
# Accuracy   : 0.9665
# Precision  : 0.9744
# Recall     : 0.9806
# F1-score   : 0.9775
# AUC        : 0.9945
#
# 🌀 Confusion Matrix:
# [[ 50   4]
#  [  3 152]]
#
# 🔹 Training DenseNet121...
# Epoch 1/50
# 284/284 [==============================] - 18s 41ms/step - loss: 0.4853 - accuracy: 0.7746 - val_loss: 0.4809 - val_accuracy: 0.7500
# Epoch 2/50
# 284/284 [==============================] - 11s 39ms/step - loss: 0.3091 - accuracy: 0.8600 - val_loss: 0.3946 - val_accuracy: 0.7589
# Epoch 3/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.2755 - accuracy: 0.8856 - val_loss: 0.4347 - val_accuracy: 0.7589
# Epoch 4/50
# 284/284 [==============================] - 11s 38ms/step - loss: 0.2602 - accuracy: 0.8882 - val_loss: 0.3466 - val_accuracy: 0.8036
# Epoch 5/50
# 284/284 [==============================] - 12s 40ms/step - loss: 0.2486 - accuracy: 0.8935 - val_loss: 0.3148 - val_accuracy: 0.8348
# Epoch 6/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.2271 - accuracy: 0.9040 - val_loss: 0.3184 - val_accuracy: 0.8214
# Epoch 7/50
# 284/284 [==============================] - 11s 38ms/step - loss: 0.2190 - accuracy: 0.9067 - val_loss: 0.2909 - val_accuracy: 0.8482
# Epoch 8/50
# 284/284 [==============================] - 12s 41ms/step - loss: 0.2048 - accuracy: 0.9093 - val_loss: 0.2596 - val_accuracy: 0.8884
# Epoch 9/50
# 284/284 [==============================] - 11s 39ms/step - loss: 0.2138 - accuracy: 0.9208 - val_loss: 0.1827 - val_accuracy: 0.9330
# Epoch 10/50
# 284/284 [==============================] - 10s 34ms/step - loss: 0.2009 - accuracy: 0.9155 - val_loss: 0.2106 - val_accuracy: 0.9152
# Epoch 11/50
# 284/284 [==============================] - 11s 38ms/step - loss: 0.1698 - accuracy: 0.9234 - val_loss: 0.1713 - val_accuracy: 0.9420
# Epoch 12/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.2037 - accuracy: 0.9234 - val_loss: 0.1892 - val_accuracy: 0.9241
# Epoch 13/50
# 284/284 [==============================] - 11s 39ms/step - loss: 0.1794 - accuracy: 0.9287 - val_loss: 0.1535 - val_accuracy: 0.9464
# Epoch 14/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1956 - accuracy: 0.9252 - val_loss: 0.1900 - val_accuracy: 0.9286
# Epoch 15/50
# 284/284 [==============================] - 11s 39ms/step - loss: 0.1805 - accuracy: 0.9208 - val_loss: 0.1457 - val_accuracy: 0.9375
# Epoch 16/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1842 - accuracy: 0.9181 - val_loss: 0.1522 - val_accuracy: 0.9330
# Epoch 17/50
# 284/284 [==============================] - 11s 38ms/step - loss: 0.1874 - accuracy: 0.9120 - val_loss: 0.1413 - val_accuracy: 0.9554
# Epoch 18/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1839 - accuracy: 0.9129 - val_loss: 0.1419 - val_accuracy: 0.9554
# Epoch 19/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1992 - accuracy: 0.9111 - val_loss: 0.1680 - val_accuracy: 0.9420
# Epoch 20/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1765 - accuracy: 0.9305 - val_loss: 0.1612 - val_accuracy: 0.9420
# Epoch 21/50
# 284/284 [==============================] - 9s 32ms/step - loss: 0.1666 - accuracy: 0.9243 - val_loss: 0.1654 - val_accuracy: 0.9375
# Epoch 22/50
# 284/284 [==============================] - 9s 33ms/step - loss: 0.1773 - accuracy: 0.9225 - val_loss: 0.1525 - val_accuracy: 0.9420
#
# ✅ Evaluating DenseNet121...
# DenseNet121 Test Loss: 0.1101, Test Acc: 0.9617
# 53/53 [==============================] - 3s 24ms/step
#
# 📊 Classification Report for DenseNet121:
#               precision    recall  f1-score   support
#
#            0     0.9423    0.9074    0.9245        54
#            1     0.9682    0.9806    0.9744       155
#
#     accuracy                         0.9617       209
#    macro avg     0.9552    0.9440    0.9494       209
# weighted avg     0.9615    0.9617    0.9615       209
#
#
# 📈 Extra Evaluation Metrics for DenseNet121:
# Accuracy   : 0.9617
# Precision  : 0.9682
# Recall     : 0.9806
# F1-score   : 0.9744
# AUC        : 0.9939
#
# 🌀 Confusion Matrix:
# [[ 49   5]
#  [  3 152]]
# ✅ Final Accuracies:
# ResNet50: 0.9665071964263916
# DenseNet121: 0.9617224931716919

# %%
# =========================
# 1. Model builder function
# =========================
def build_model(base_model, input_shape):
    base_model.trainable = True  # unfreeze base model
    inputs = tf.keras.Input(shape=input_shape)
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    
    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-5),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# =========================
# 2. Training and evaluation function
# =========================
def train_and_evaluate(model_name, base_model, train_ds, val_ds, test_ds, input_shape, epochs=50):
    print(f"\n🔹 Training {model_name}...")
    model = build_model(base_model, input_shape)
    
    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    )
    
    checkpoint = ModelCheckpoint(
        f'best_{model_name}_unfreezed.h5',
        monitor='val_loss',
        save_best_only=True
    )
    
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=[early_stop, checkpoint]
    )
    
    print(f"\n✅ Evaluating {model_name}...")
    results = model.evaluate(test_ds, verbose=0)
    test_loss, test_acc = results[0], results[1]
    print(f"{model_name} Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
    
    # =========================
    # Predictions
    # =========================
    y_true = np.concatenate([y for _, y in test_ds], axis=0)   # ground truth labels
    y_pred_probs = model.predict(test_ds)
    y_pred = (y_pred_probs > 0.5).astype("int32").ravel()
    
    # =========================
    # Classification report
    # =========================
    print(f"\n📊 Classification Report for {model_name}:")
    print(classification_report(y_true, y_pred, digits=4))
    
    # =========================
    # Extra metrics
    # =========================
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred_probs)
    acc = accuracy_score(y_true, y_pred)
    
    print(f"\n📈 Extra Evaluation Metrics for {model_name}:")
    print(f"Accuracy   : {acc:.4f}")
    print(f"Precision  : {precision:.4f}")
    print(f"Recall     : {recall:.4f}")
    print(f"F1-score   : {f1:.4f}")
    print(f"AUC        : {auc:.4f}")
    
    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    print("\n🌀 Confusion Matrix:")
    print(cm)
    
    # return model, history, and accuracy
    return model, history, test_acc

# =========================
# 3. Prepare base models
# =========================
# ResNet50 (224x224)
resnet_base = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(224,224,3))

# DenseNet121 (224x224)
densenet_base = tf.keras.applications.DenseNet121(include_top=False, weights='imagenet', input_shape=(224,224,3))

# =========================
# 4. Train models
# =========================
resnet_model_unfreezed, resnet_history_unfreezed, resnet_acc_unfreezed = train_and_evaluate(
    "ResNet50", resnet_base, train_ds_resnet, val_ds_resnet, test_ds_resnet, (224,224,3)
)

densenet_model_unfreezed, densenet_history_unfreezed, densenet_acc_unfreezed = train_and_evaluate(
    "DenseNet121", densenet_base, train_ds_densenet, val_ds_densenet, test_ds_densenet, (224,224,3)
)

print("✅ Final Accuracies:")
print("ResNet50:", resnet_acc_unfreezed)
print("DenseNet121:", densenet_acc_unfreezed)
# Out:
# 🔹 Training ResNet50...
# Epoch 1/50
# 284/284 [==============================] - 36s 106ms/step - loss: 0.2913 - accuracy: 0.8847 - val_loss: 0.0965 - val_accuracy: 0.9688
# Epoch 2/50
# 284/284 [==============================] - 29s 100ms/step - loss: 0.1298 - accuracy: 0.9551 - val_loss: 0.1393 - val_accuracy: 0.9732
# Epoch 3/50
# 284/284 [==============================] - 37s 131ms/step - loss: 0.1132 - accuracy: 0.9674 - val_loss: 0.0386 - val_accuracy: 0.9911
# Epoch 4/50
# 284/284 [==============================] - 29s 100ms/step - loss: 0.0765 - accuracy: 0.9718 - val_loss: 0.0707 - val_accuracy: 0.9866
# Epoch 5/50
# 284/284 [==============================] - 28s 100ms/step - loss: 0.0705 - accuracy: 0.9780 - val_loss: 0.0698 - val_accuracy: 0.9821
# Epoch 6/50
# 284/284 [==============================] - 38s 133ms/step - loss: 0.0569 - accuracy: 0.9815 - val_loss: 0.0252 - val_accuracy: 0.9911
# Epoch 7/50
# 284/284 [==============================] - 29s 100ms/step - loss: 0.0517 - accuracy: 0.9815 - val_loss: 0.0315 - val_accuracy: 0.9911
# Epoch 8/50
# 284/284 [==============================] - 28s 100ms/step - loss: 0.0558 - accuracy: 0.9850 - val_loss: 0.1023 - val_accuracy: 0.9777
# Epoch 9/50
# 284/284 [==============================] - 28s 100ms/step - loss: 0.0541 - accuracy: 0.9842 - val_loss: 0.0625 - val_accuracy: 0.9866
# Epoch 10/50
# 284/284 [==============================] - 28s 100ms/step - loss: 0.0417 - accuracy: 0.9850 - val_loss: 0.0935 - val_accuracy: 0.9732
# Epoch 11/50
# 284/284 [==============================] - 28s 100ms/step - loss: 0.0467 - accuracy: 0.9824 - val_loss: 0.0447 - val_accuracy: 0.9777
#
# ✅ Evaluating ResNet50...
# ResNet50 Test Loss: 0.0360, Test Acc: 0.9904
# 53/53 [==============================] - 2s 24ms/step
#
# 📊 Classification Report for ResNet50:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9630    0.9811        54
#            1     0.9873    1.0000    0.9936       155
#
#     accuracy                         0.9904       209
#    macro avg     0.9936    0.9815    0.9874       209
# weighted avg     0.9906    0.9904    0.9904       209
#
#
# 📈 Extra Evaluation Metrics for ResNet50:
# Accuracy   : 0.9904
# Precision  : 0.9873
# Recall     : 1.0000
# F1-score   : 0.9936
# AUC        : 0.9994
#
# 🌀 Confusion Matrix:
# [[ 52   2]
#  [  0 155]]
#
# 🔹 Training DenseNet121...
# Epoch 1/50
# 284/284 [==============================] - 45s 118ms/step - loss: 0.4016 - accuracy: 0.8151 - val_loss: 0.2406 - val_accuracy: 0.9107
# Epoch 2/50
# 284/284 [==============================] - 36s 126ms/step - loss: 0.1613 - accuracy: 0.9516 - val_loss: 0.0625 - val_accuracy: 0.9866
# Epoch 3/50
# 284/284 [==============================] - 32s 110ms/step - loss: 0.1048 - accuracy: 0.9639 - val_loss: 0.0707 - val_accuracy: 0.9777
# Epoch 4/50
# 284/284 [==============================] - 35s 124ms/step - loss: 0.1066 - accuracy: 0.9665 - val_loss: 0.0500 - val_accuracy: 0.9821
# Epoch 5/50
# 284/284 [==============================] - 36s 125ms/step - loss: 0.0804 - accuracy: 0.9771 - val_loss: 0.0479 - val_accuracy: 0.9955
# Epoch 6/50
# 284/284 [==============================] - 32s 111ms/step - loss: 0.0850 - accuracy: 0.9736 - val_loss: 0.0775 - val_accuracy: 0.9821
# Epoch 7/50
# 284/284 [==============================] - 36s 125ms/step - loss: 0.0662 - accuracy: 0.9789 - val_loss: 0.0222 - val_accuracy: 0.9911
# Epoch 8/50
# 284/284 [==============================] - 31s 107ms/step - loss: 0.0879 - accuracy: 0.9762 - val_loss: 0.0316 - val_accuracy: 0.9911
# Epoch 9/50
# 284/284 [==============================] - 32s 112ms/step - loss: 0.0755 - accuracy: 0.9771 - val_loss: 0.0363 - val_accuracy: 0.9777
# Epoch 10/50
# 284/284 [==============================] - 31s 110ms/step - loss: 0.0495 - accuracy: 0.9850 - val_loss: 0.0315 - val_accuracy: 0.9911
# Epoch 11/50
# 284/284 [==============================] - 31s 110ms/step - loss: 0.0593 - accuracy: 0.9798 - val_loss: 0.0332 - val_accuracy: 0.9911
# Epoch 12/50
# 284/284 [==============================] - 35s 124ms/step - loss: 0.0526 - accuracy: 0.9842 - val_loss: 0.0206 - val_accuracy: 0.9911
# Epoch 13/50
# 284/284 [==============================] - 36s 125ms/step - loss: 0.0486 - accuracy: 0.9850 - val_loss: 0.0138 - val_accuracy: 0.9911
# Epoch 14/50
# 284/284 [==============================] - 31s 109ms/step - loss: 0.0357 - accuracy: 0.9877 - val_loss: 0.0157 - val_accuracy: 0.9911
# Epoch 15/50
# 284/284 [==============================] - 35s 125ms/step - loss: 0.0407 - accuracy: 0.9886 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 16/50
# 284/284 [==============================] - 35s 124ms/step - loss: 0.0379 - accuracy: 0.9886 - val_loss: 0.0094 - val_accuracy: 0.9955
# Epoch 17/50
# 284/284 [==============================] - 31s 108ms/step - loss: 0.0447 - accuracy: 0.9842 - val_loss: 0.0285 - val_accuracy: 0.9911
# Epoch 18/50
# 284/284 [==============================] - 31s 108ms/step - loss: 0.0402 - accuracy: 0.9798 - val_loss: 0.0150 - val_accuracy: 0.9911
# Epoch 19/50
# 284/284 [==============================] - 31s 110ms/step - loss: 0.0297 - accuracy: 0.9912 - val_loss: 0.0113 - val_accuracy: 0.9955
# Epoch 20/50
# 284/284 [==============================] - 31s 109ms/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.0246 - val_accuracy: 0.9955
# Epoch 21/50
# 284/284 [==============================] - 35s 122ms/step - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.0057 - val_accuracy: 0.9955
# Epoch 22/50
# 284/284 [==============================] - 31s 108ms/step - loss: 0.0387 - accuracy: 0.9886 - val_loss: 0.0241 - val_accuracy: 0.9866
# Epoch 23/50
# 284/284 [==============================] - 32s 113ms/step - loss: 0.0271 - accuracy: 0.9886 - val_loss: 0.0388 - val_accuracy: 0.9821
# Epoch 24/50
# 284/284 [==============================] - 31s 108ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 25/50
# 284/284 [==============================] - 31s 108ms/step - loss: 0.0405 - accuracy: 0.9868 - val_loss: 0.0188 - val_accuracy: 0.9911
# Epoch 26/50
# 284/284 [==============================] - 31s 110ms/step - loss: 0.0243 - accuracy: 0.9903 - val_loss: 0.0093 - val_accuracy: 0.9955
#
# ✅ Evaluating DenseNet121...
# DenseNet121 Test Loss: 0.0246, Test Acc: 0.9904
# 53/53 [==============================] - 3s 25ms/step
#
# 📊 Classification Report for DenseNet121:
#               precision    recall  f1-score   support
#
#            0     0.9815    0.9815    0.9815        54
#            1     0.9935    0.9935    0.9935       155
#
#     accuracy                         0.9904       209
#    macro avg     0.9875    0.9875    0.9875       209
# weighted avg     0.9904    0.9904    0.9904       209
#
#
# 📈 Extra Evaluation Metrics for DenseNet121:
# Accuracy   : 0.9904
# Precision  : 0.9935
# Recall     : 0.9935
# F1-score   : 0.9935
# AUC        : 0.9994
#
# 🌀 Confusion Matrix:
# [[ 53   1]
#  [  1 154]]
# ✅ Final Accuracies:
# ResNet50: 0.9904305934906006
# DenseNet121: 0.9904305934906006
